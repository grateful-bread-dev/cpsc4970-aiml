# %% [markdown]
# CPSC 4970 M0 Homework - Jonathan Braun

# %%
import sys
print("Python version:", sys.version)

import pandas as pd
print("pandas version:", pd.__version__)

import matplotlib
print("matplotlib version:", matplotlib.__version__)

import seaborn as sns
print("seaborn version:", sns.__version__)

import numpy as np
print("NumPy version:", np.__version__)

import scipy as sp
print("SciPy version:", sp.__version__)

import IPython
print("IPython version:", IPython.__version__)

import sklearn
print("scikit-learn version:", sklearn.__version__)

import mglearn
print("mglearn version:", mglearn.__version__)
# Out:
# Python version: 3.12.12 (main, Dec  9 2025, 19:02:36) [Clang 21.1.4 ]
# pandas version: 3.0.3
# matplotlib version: 3.10.9
# seaborn version: 0.13.2
# NumPy version: 2.4.6
# SciPy version: 1.17.1
# IPython version: 9.13.0
# scikit-learn version: 1.8.0
# mglearn version: 0.1.9
# /home/gratefulbread/Documents/cpsc4970-aiml/.venv/lib/python3.12/site-packages/mglearn/datasets.py:37: SyntaxWarning: invalid escape sequence '\s'
#   raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)

# %% [markdown]
# #1

# %%
v = np.array([[1, 2, -1, 3]])
w = np.array([[5], [4], [1], [0]])
A = np.array([[1, 0, 1], [2, 1, 1], [1, -1, 0], [0, 0, 2]])
B = np.array([[1, 1, 3, 6], [1, -1, 0, 2], [0, 0, 1, 3]])

print(f"{v + v = }")
# Out:
# v + v = array([[ 2,  4, -2,  6]])

# %% [markdown]
# #2

# %%
print(f"{2 * v = }")
# Out:
# 2 * v = array([[ 2,  4, -2,  6]])

# %% [markdown]
# #3

# %%
print(f"{v.T + w =}")
# Out:
# v.T + w =array([[6],
#        [6],
#        [0],
#        [3]])

# %% [markdown]
# #4

# %%
print(f"{v + w.T =}")
# Out:
# v + w.T =array([[6, 6, 0, 3]])

# %% [markdown]
# #5

# %%
print(f"{v.T - w =}")
# Out:
# v.T - w =array([[-4],
#        [-2],
#        [-2],
#        [ 3]])

# %% [markdown]
# #6

# %%
print(f"{w - v.T =}")
# Out:
# w - v.T =array([[ 4],
#        [ 2],
#        [ 2],
#        [-3]])

# %% [markdown]
# #7

# %%
print(f"{v + (2 * w.T) =}")
# Out:
# v + (2 * w.T) =array([[11, 10,  1,  3]])

# %% [markdown]
# #8

# %%
print(f"{v * w.T =}")
# Out:
# v * w.T =array([[ 5,  8, -1,  0]])

# %% [markdown]
# #9

# %%
print(f"{v @ w =}")
# Out:
# v @ w =array([[12]])

# %% [markdown]
# #10

# %%
print(f"{w.T @ v.T =}")
# Out:
# w.T @ v.T =array([[12]])

# %% [markdown]
# #11

# %%
print(f"{w.T @ w =}")
# Out:
# w.T @ w =array([[42]])

# %% [markdown]
# #12

# %%
print(f"{v @ v.T =}")
# Out:
# v @ v.T =array([[15]])

# %% [markdown]
# #13

# %%
print(f"{v @ A =}")
# Out:
# v @ A =array([[4, 3, 9]])

# %% [markdown]
# #14

# %%
print(f"{A @ B =}")
# Out:
# A @ B =array([[ 1,  1,  4,  9],
#        [ 3,  1,  7, 17],
#        [ 0,  2,  3,  4],
#        [ 0,  0,  2,  6]])

# %% [markdown]
# #15

# %%
print(f"{v @ A @ B =}")
# Out:
# v @ A @ B =array([[ 7,  1, 21, 57]])

# %% [markdown]
# #16

# %%
print(f"{A.T @ A =}")
# Out:
# A.T @ A =array([[6, 1, 3],
#        [1, 2, 1],
#        [3, 1, 6]])

# %% [markdown]
# #17

# %%
print(f"{(B @ B.T) - (A.T @ A) =}")
# Out:
# (B @ B.T) - (A.T @ A) =array([[41, 11, 18],
#        [11,  4,  5],
#        [18,  5,  4]])

# %% [markdown]
# #18

# %%
print(f"{A * B.T =}")
# Out:
# A * B.T =array([[ 1,  0,  0],
#        [ 2, -1,  0],
#        [ 3,  0,  0],
#        [ 0,  0,  6]])

# %% [markdown]
# #19

# %%
print(f"{v.T @ w.T =}")
# Out:
# v.T @ w.T =array([[ 5,  4,  1,  0],
#        [10,  8,  2,  0],
#        [-5, -4, -1,  0],
#        [15, 12,  3,  0]])

# %% [markdown]
# #20

# %%
print(f"{w @ v =}")
# Out:
# w @ v =array([[ 5, 10, -5, 15],
#        [ 4,  8, -4, 12],
#        [ 1,  2, -1,  3],
#        [ 0,  0,  0,  0]])
